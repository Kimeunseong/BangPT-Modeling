# %%
# import cv2

# # 입력 동영상 파일 경로와 이름
# input_file = 'input_video.mp4'

# # 출력 동영상 파일 경로와 이름의 접두사
# output_prefix = 'output_video_'

# # 자를 영상 길이(단위: 초)
# interval = 3

# # OpenCV로 동영상 파일 열기
# cap = cv2.VideoCapture(input_file)

# # 동영상의 프레임 레이트와 프레임 크기 가져오기
# fps = cap.get(cv2.CAP_PROP_FPS)
# width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
# height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# # 코덱 설정
# fourcc = cv2.VideoWriter_fourcc(*'mp4v')

# # 현재 프레임 번호
# frame_num = 0

# # 출력 동영상 인덱스
# output_index = 1

# # 출력 동영상 객체 생성
# output_file = output_prefix + str(output_index) + '.mp4'
# out = cv2.VideoWriter(output_file, fourcc, fps, (width, height))

# # 비디오 읽기 반복문
# while True:
#     # 프레임 읽기
#     ret, frame = cap.read()
    
#     # 프레임을 모두 읽었을 경우 종료
#     if not ret:
#         break
    
#     # 자를 영상 길이마다 동영상 크롭하여 저장
#     if frame_num % (interval * fps) == 0:
#         # 이전 출력 동영상 닫기
#         out.release()
        
#         # 새로운 출력 동영상 파일 생성
#         output_index += 1
#         output_file = output_prefix + str(output_index) + '.mp4'
#         out = cv2.VideoWriter(output_file, fourcc, fps, (width, height))
    
#     # 현재 프레임을 출력 동영상에 저장
#     out.write(frame)
    
#     # 다음 프레임 읽기
#     frame_num += 1

# # 파일 닫기
# cap.release()
# out.release()

# %%
# import cv2

# # 입력 동영상 파일 경로와 이름
# input_file = './data/total_0513/4_test_data/IMG_0438.mov'

# # 출력 동영상 파일 경로와 이름의 접두사
# output_prefix = './data/total_0513/4_test_data/test02/video_'

# # 자를 영상 길이(단위: 초)
# interval = 3

# # OpenCV로 동영상 파일 열기
# cap = cv2.VideoCapture(input_file)

# # 동영상의 프레임 레이트와 프레임 크기 가져오기
# fps = cap.get(cv2.CAP_PROP_FPS)
# width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
# height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# # 코덱 설정
# fourcc = cv2.VideoWriter_fourcc(*'mp4v')

# # 현재 프레임 번호
# frame_num = 0

# # 출력 동영상 인덱스
# output_index = 0

# # 비디오 읽기 반복문
# while True:
#     # 프레임 읽기
#     ret, frame = cap.read()
    
#     # 프레임을 모두 읽었을 경우 종료
#     if not ret:
#         break
    
#     # 자를 영상 길이마다 동영상 크롭하여 저장
#     if frame_num % (interval * fps) == 0:
#         # 새로운 출력 동영상 파일 생성
#         output_file = output_prefix + str(output_index) + '.mp4'
#         out = cv2.VideoWriter(output_file, fourcc, fps, (width, height))
        
#         # 출력 동영상의 길이 계산
#         output_duration = min(interval, (cap.get(cv2.CAP_PROP_FRAME_COUNT) - frame_num) / fps)
        
#         # 현재 프레임부터 출력 동영상의 길이만큼 저장
#         for _ in range(int(output_duration * fps)):
#             out.write(frame)
    
#         output_index += 1
    
#     # 현재 프레임을 출력 동영상에 저장
#     out.write(frame)
    
#     # 다음 프레임 읽기
#     frame_num += 1

# # 파일 닫기
# cap.release()
# out.release()

# %%
# import cv2
# import numpy as np
# from matplotlib import pyplot as plt
# import os
# from PIL import Image

# # print(os.getcwd())
# # #파이썬 경로를 비디오 경로와 동일하게 변경
# # os.chdir('D:/my/record_3')
# # print(os.getcwd())

# videopath = 'D:/my/record_3/'
# savepath = 'D:/my/video frame/rec3/'


# for i in range(9,901):
#     vname = 'v_3_'+str(i)
#     #print(vname)
#     cap = cv2.VideoCapture(videopath+vname+'.mp4')  
#     fps = cap.get(cv2.CAP_PROP_FPS)
#     length = cap.get(cv2.CAP_PROP_FRAME_COUNT)
#     duration = length / fps
#     print(vname,', ',duration)


#     second = 0 # 초
#     num = 0  # 캡쳐 횟수 카운터
#     increase_width = 3  # 몇 초마다 캡쳐를 하고 싶은지 (증가폭)

#     cap.set(cv2.CAP_PROP_POS_MSEC, second * 1000) # openCV가 마이크로 세컨드 (ms)를 쓰기 때문에 1초는 1000을 입력해야함
#     success, image = cap.read()


#     while success and second <= duration:
#         num += 1
#         second += increase_width  # 증가폭
#         #print("이번 캡쳐할 시간대는", second, "초")
#         cap.set(cv2.CAP_PROP_POS_MSEC, second * 1000)
#         success, image = cap.read()
#         #second가 높으면저장안됨
#         if second >= duration:
#             break
#         cv2.imwrite(savepath+"f_"+vname+"_%d.jpg" % num, image)
#     print('ok ',vname)
#         #plt.imshow(image)
#         #plt.show()

# %%
# import cv2

# def save_video_segments1(input_file, output_prefix, segment_length):
#     # 동영상 파일 열기
#     cap = cv2.VideoCapture(input_file)

#     # 동영상 속성 가져오기
#     frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
#     frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
#     fps = cap.get(cv2.CAP_PROP_FPS)
#     total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

#     # 세그먼트 길이를 프레임 단위로 변환
#     segment_length_frames = int(segment_length * fps)

#     # 저장할 세그먼트 번호 초기화
#     segment_number = 1

#     while True:
#         # 세그먼트 시작 프레임 설정
#         start_frame = (segment_number - 1) * segment_length_frames

#         # 동영상의 현재 프레임 설정
#         cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)

#         # 세그먼트의 첫 번째 프레임 읽기
#         ret, frame = cap.read()

#         # 세그먼트를 모두 읽었을 때 종료
#         if not ret:
#             break

#         # 세그먼트 파일 이름 설정
#         output_file = f"{output_prefix}_{segment_number}.mp4"

#         # 세그먼트 파일 생성
#         out = cv2.VideoWriter(output_file, cv2.VideoWriter_fourcc(*'XVID'), fps, (frame_width, frame_height))

#         # 세그먼트 길이만큼 프레임 저장
#         for i in range(segment_length_frames):
#             # 동영상의 현재 프레임 읽기
#             ret, frame = cap.read()

#             # 프레임 저장
#             out.write(frame)

#         # 세그먼트 파일 닫기
#         out.release()

#         # 다음 세그먼트 번호로 이동
#         segment_number += 1

#     # 동영상 파일 닫기
#     cap.release()

#     print("동영상 세그먼트 저장이 완료되었습니다.")

# %%
# # 사용 예시
# input_file = "./data/total_0513/4_test_data/IMG_0438.mov"
# output_prefix = "./data/total_0513/4_test_data/test02/output_segment"
# segment_length = 3  # 세그먼트 길이 (초)

# save_video_segments1(input_file, output_prefix, segment_length)
# Out:
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 동영상 세그먼트 저장이 완료되었습니다.
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# ...

# %%
import cv2

def save_video_segments2(input_file, output_prefix, segment_count):
    # 동영상 파일 열기
    cap = cv2.VideoCapture(input_file)

    # 동영상 속성 가져오기
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    # 세그먼트 길이 계산
    segment_length_frames = total_frames // segment_count

    # 저장할 세그먼트 번호 초기화
    segment_number = 1

    frame_count = 0
    while segment_number <= segment_count:
        # 동영상의 현재 프레임 설정
        cap.set(cv2.CAP_PROP_POS_FRAMES, frame_count)

        # 세그먼트 파일 이름 설정
        output_file = f"{output_prefix}_{segment_number}.mp4"

        # 세그먼트 파일 생성
        out = cv2.VideoWriter(output_file, cv2.VideoWriter_fourcc(*'XVID'), fps, (frame_width, frame_height))

        # 세그먼트 길이만큼 프레임 저장
        for i in range(segment_length_frames):
            # 동영상의 현재 프레임 읽기
            ret, frame = cap.read()

            # 프레임 저장
            out.write(frame)

        # 세그먼트 파일 닫기
        out.release()

        # 다음 세그먼트 번호로 이동
        segment_number += 1

        # 다음 세그먼트의 시작 프레임 설정
        frame_count += segment_length_frames

    # 동영상 파일 닫기
    cap.release()

    print("동영상 세그먼트 저장이 완료되었습니다.")

# %%
# 사용 예시
input_file = "./data/total_0513/4_test_data/IMG_0438.mov"
output_prefix = "./data/total_0513/4_test_data/test03/output_segment"
segment_count = 5  # 세그먼트 개수

save_video_segments2(input_file, output_prefix, segment_count)
# Out:
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 동영상 세그먼트 저장이 완료되었습니다.

# %%
# 사용 예시2
input_file = "./data/total_0513/4_test_data/IMG_4547.mov"
output_prefix = "./data/total_0513/4_test_data/test04/output_segment"
segment_count = 5  # 세그먼트 개수

save_video_segments2(input_file, output_prefix, segment_count)
# Out:
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 동영상 세그먼트 저장이 완료되었습니다.

# %%
# 동영상 정보 확인

import cv2

def video_info(infilename):
 
    cap = cv2.VideoCapture(infilename)
 
    if not cap.isOpened():
        print("could not open :", infilename)
        exit(0)
 
    length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)
 
    print('length : ', length)
    print('width : ', width)
    print('height : ', height)
    print('fps : ', fps)

# %%
infilename = './data/total_0513/4_test_data/test03/output_segment_1.mp4'
video_info(infilename)
# Out:
# length :  90
# width :  720
# height :  1280
# fps :  29.865

# %%
# 분할된 동영상의 프레임이 모두 같은지 확인하기

import os

lst = []
path = './data/total_0513/4_test_data/test03/'
for i in sorted(os.listdir(path)):
    lst.append(i)
    
for i in lst:
    infilename = path + i
    print(f'동영상 {i} 정보')
    video_info(infilename)
    print()
# Out:
# 동영상 output_segment_1.mp4 정보
# length :  90
# width :  720
# height :  1280
# fps :  29.865
#
# 동영상 output_segment_2.mp4 정보
# length :  90
# width :  720
# height :  1280
# fps :  29.865
#
# 동영상 output_segment_3.mp4 정보
# length :  90
# width :  720
# height :  1280
# fps :  29.865
#
# 동영상 output_segment_4.mp4 정보
# length :  90
# width :  720
# height :  1280
# fps :  29.865
#
# 동영상 output_segment_5.mp4 정보
# length :  87
# width :  720
# height :  1280
# fps :  29.865
